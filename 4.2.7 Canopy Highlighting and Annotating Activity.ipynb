# %% [markdown]
# ## 4.1.9 Create plots with Seaborn

# %%
# Import Matplotlib, Seaborn, and Pandas.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Imporve the DPI of the charts
plt.rcParams['figure.dpi'] = 144
plt.rcParams['savefig.dpi'] = 300
sns.set(rc={"figure.dpi":144, 'savefig.dpi':300})
sns.set_context('notebook')
sns.set_style("ticks")
sns.color_palette("Set2")
sns.despine()

# %%
# Import packages and read data files

# %%
import matplotlib as plt
import seaborn as sns
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')
ott = pd.read_excel('ott.xlsx')

# %%
print(movies.shape)
print(movies.dtypes)
print(movies.columns)
# Out:
# (16744, 11)
# ID                   int64
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes     object
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')

# %%
movies.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# ...

# %%
print(ott.shape)
print(ott.dtypes)
print(ott.columns)
# Out:
# (16744, 5)
# ID             int64
# Netflix        int64
# Hulu           int64
# Prime Video    int64
# Disney+        int64
# dtype: object
# Index(['ID', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], dtype='object')

# %%
ott.head()
# Out:
#    ID  Netflix  Hulu  Prime Video  Disney+
# 0   1        0     0            1        0
# 1   2        0     1            0        0
# 2   3        0     0            1        0
# 3   4        1     0            0        0
# 4   5        0     0            1        0

# %% [markdown]
# ### Merge the dataframes

# %%
# Left Merge with movies being left
# Merge on ID

# %%
movies_ott = pd.merge(movies, ott, how='left', on='ID')

# %%
movies_ott.columns
# Out:
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime', 'Netflix', 'Hulu',
#        'Prime Video', 'Disney+'],
#       dtype='object')

# %%
movies_ott.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime  Netflix  \
# ...

# %%
# Create a countplot to determin which age group has downloaded the most movies

# %%
sns.countplot(x='Age', hue='Netflix', data=movies_ott)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# Q2 A The 18+ age group has streamed the most movies

# %% [markdown]
# Q2 B Netflix does not have the majority share of each streaming service by any of the age groups.

# %%
sns.countplot(x='Age', data=movies_ott)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
# Create a histogram based on IMDb. 
sns.histplot(data=movies_ott, x='IMDb', binwidth=1)
# Out:
# <AxesSubplot:xlabel='IMDb', ylabel='Count'>

# %% [markdown]
# Q3 A Most ratings are between 5 and 7. Distribution is left skewed.

# %% [markdown]
# Q3 B Data outliers are scores of 8 to 10.

# %%
# Create a scatterplot to show correclation between ratings for Rotten Tomatoes and IMDb

# %%
sns.scatterplot(x='Rotten Tomatoes', y='IMDb', data=movies_ott)
# Out:
# <AxesSubplot:xlabel='Rotten Tomatoes', ylabel='IMDb'>

# %%
sns.scatterplot(x='Rotten Tomatoes', y='IMDb', legend='full', data=movies_ott)
# Out:
# <AxesSubplot:xlabel='Rotten Tomatoes', ylabel='IMDb'>

# %% [markdown]
# Q4 A Data suggests that higher IMDb ratings have a lower corresponding Rotten Tomatoes rating

# %% [markdown]
# Q4 B Moderate, negative correlation

# %% [markdown]
# ## 4.2.7 Practical Activity

# %% [markdown]
# Use hue on Netflix to categorise the scatter plot

# %%
sns.scatterplot(data=movies_ott, x='IMDb', y='Rotten Tomatoes', hue='Netflix')

plt.show()

# %% [markdown]
# Can infer that there are less Netflix data points that others and that evenly distributed

# %%
movies_ott.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime  Netflix  \
# ...

# %%
sns.boxplot(x='Age', y='IMDb', data=movies_ott)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='IMDb'>

# %% [markdown]
# ## 4.2.7 Customise boxplots to add linewidth, hue and palette

# %%
sns.boxplot(data=movies_ott, x='Age', y='IMDb', linewidth=0.5, 
            notch=True, hue='Netflix', palette='Set3')

plt.show()

# %% [markdown]
# ## 4.1.15 Practical Activity

# %% [markdown]
# Plot a lineplot to identify possible trends by comparing movie release year and IMDb ratings

# %%
# View the merged DF

# %%
movies_ott.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime  Netflix  \
# ...

# %%
# import all the packages

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import *

# %%
sns.lineplot(x='Year', y='IMDb', data=movies_ott)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='IMDb'>

# %%
# get rid of the confidence interval

# %%
sns.lineplot(x='Year', y='IMDb', data=movies_ott[movies_ott['Age'].isin(['16+', '18+'])], hue ='Age', ci=None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='IMDb'>

# %%
# Aggregate data to achieve a mean rating per year

# %%
annual_rating = movies_ott.groupby('Year')[['IMDb']].mean().reset_index().copy()

# %%
annual_rating.head()
# Out:
#    Year  IMDb
# 0  1902  8.20
# 1  1912  5.70
# 2  1913  5.15
# 3  1915  5.55
# 4  1916  7.80

# %%
# Now try creating the plot again

# %%
sns.lineplot(x='Year', y='IMDb', data=annual_rating)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='IMDb'>

# %%
sns.lineplot(x='Year', y='IMDb', data=annual_rating, ci=None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='IMDb'>

# %% [markdown]
# Q2a) Rating for movies released between 1920 and 1940 vary greatly: 1920's high rating, 1930s very low rating

# %% [markdown]
# Q2b) Rating for movies released between 1960 and 1980 are generally rated as low as the 1930's and 1940's movies - no high

# %% [markdown]
# ## Customer lineplot by changing the linewidth to zero

# %%
sns.lineplot(x = 'Year', y = 'IMDb', data=movies_ott, linewidth=0)

sns.lineplot(x = 'Year', y = 'IMDb',
             data=movies_ott[movies_ott['Age'].isin(["'16+', '18+'])], 
             hue ='Age')

sns.lineplot(x = 'Year', y = 'IMDb', 
             data=movies_ott[movies_ott['Age'].isin(['16+', '18+'])], 
             hue ='Age', style = 'Age', markers=True, ci=0)
# Out:
#   File "/var/folders/_7/y9fnwxrn44d7m__w6dc1vy4w0000gn/T/ipykernel_2401/1633132802.py", line 4
#     data=movies_ott[movies_ott['Age'].isin(["'16+', '18+'])],
#                                                               ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ### Enhance the lineplot to include a comparison between age, rating and year of release

# %%
# Create lineplots with specification.
sns.lineplot(x = 'Year', y = 'IMDb',
             data=movies_ott[movies_ott['Age'].isin(['16+', '18+'])],
             hue ='Age', markers=True, ci=None)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='IMDb'>

# %% [markdown]
# Q3 You can infer that ratings for those aged 16+ were not collected before 1970.

# %% [markdown]
# ## 4.2.5 Practical Activity

# %% [markdown]
# Subset data to show movied viewed since 2010

# %%
movies_ott_2010 = movies_ott[movies_ott['Year']>=2010]

# %% [markdown]
# Use percentage to understand the data distribution followed by rotating label by 90 degrees

# %%
movies_ott_2010 = movies_ott[movies_ott['Year']>=2010]

ax = sns.countplot(x='Year', data=movies_ott_2010)

ax.set(ylabel='Percent')

total = len(movies_ott_2010['Year'])

for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x()
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Add a line to the visualisation to see whether the data is normally distributed

# %%
ax = sns.displot(data=movies_ott_2010, x='IMDb', bins=10,kind='hist', 
                 palette='GnBu', aspect=1.4, kde=True)

plt.show()
